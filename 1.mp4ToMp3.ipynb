# %%
# What We’ll Build in This Project -

# In this project, we’ll build a RAG-based AI Teaching Assistant designed for our Data Science course.
# Using Retrieval-Augmented Generation (RAG), the assistant will be able to fetch relevant information
# from course materials and provide accurate, context-aware answers—just like a real teaching assistant.

# Step 1.
# I wrote a python program that converted all the MP4 files into MP3's since whisper ( a module which we will later
# use in this project that basically helps to convert speech to text ) takes MP3's, and saved all the converted mp3s in
# a folder named "audios", made by using os module. Saved the program under 1.mp4ToMp3.ipynb.


# information ----------------Tools that we used here ----------- Information -----------------

# " FFmpeg "

# FFmpeg is a command-line tool/library that can:
    
# Load audio/video files
# Convert between formats
# Extract audio from video
# Resample audio
# Cut, merge, compress, etc.
# Whisper needs FFmpeg because Whisper cannot directly read .mp3, .mp4, .wav, etc.
# FFmpeg decodes them and hands raw audio to Whisper.

#-----------------------------------------------------------------------------------------------

# " Whisper "     -       OpenAI’s automatic speech-to-text model    
# It listens to audio/video and converts speech into text — super accurately.

# Think of it as:
# “The model that turns voice into subtitles/transcripts.”

# Transcribe audio → text
# Generate subtitles for videos
# Translate speech from one language to English
# Handle noisy audio extremely well
# Understand many languages automatically
# Work fully offline on your computer
#-----------------------------------------------------------------------------------------------

# %%
# As I downloaded 10 videos from YouTube related to Python that has 10 lectures of around 20-30 minutes each.
# now we will convert these videos into mp3's using ffmpeg/ subprocess in python, for which the code is right below :

import subprocess          # Subprocess Allows Python to run external programs (like ffmpeg).

input_file = "/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp4"
output_file = "/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3"

subprocess.run(["ffmpeg", "-i", input_file, output_file])        # sb.run - takes a list of command line arguments
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x121704310] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     title           : Lecture 10: Understanding Program Efficiency, Part 1
#     artist          : Prof. Eric Grimson
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : algorithmic complexity, big oh, runtime, complexity classes, efficiency, linear complexity, quadratic complexity
#   Duration: 00:51:25.72, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:18.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# File '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3' already exists. Overwrite? [y/N] Not overwriting - exiting
# Error opening output file /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3.
# CompletedProcess(args=['ffmpeg', '-i', '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp4', '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3'], returncode=0)

# %%
import subprocess       # Allows Python to run external programs (like ffmpeg).
import os              # os module provides functions for interacting with the operating system
import glob

# glob is a module that can search for files using patterns.
# Example pattern: "*.mp4" means “all files ending with .mp4”.

folder = "/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos"

# Get ALL .mp4 files in the folder
mp4_files = glob.glob(os.path.join(folder, "*.mp4"))

for mp4 in mp4_files:
    mp3 = mp4.replace(".mp4", ".mp3")
    print(f"Converting: {mp4} → {mp3}")
    
    subprocess.run(["ffmpeg", "-y", "-i", mp4, mp3])
# Out:
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_01_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_01_300k.mp3
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x122606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_01_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Lecture 1: What is Computation?
#     episode_id      : 000
#     encoder         : Lavf55.18.100
#     rating          : 0
#     artist          : Dr. Ana Bell
#     date            : 2016-09-06T20:00:00Z
#     genre           : MIT Faculty Lecture
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     album_artist    : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     synopsis        : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     media_type      : 0
#     keywords        : Python, theory of computation, syntax, programming language
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#   Duration: 00:43:05.96, start: 0.000000, bitrate: 312 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, start 0.044000 (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x54, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2019-07-30T18:45:22.000000Z
#   Stream #0:3[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:3 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_01_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     TIT2            : Lecture 1: What is Computation?
#     episode_id      : 000
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     rating          : 0
#     TPE1            : Dr. Ana Bell
#     TDRC            : 2016-09-06T20:00:00Z
#     TCON            : MIT Faculty Lecture
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     TPE2            : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     synopsis        : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     media_type      : 0
#     keywords        : Python, theory of computation, syntax, programming language
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x60000349c000] video:2225KiB audio:40406KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003569%
# frame=    1 fps=0.0 q=-0.0 Lsize=   42632KiB time=00:00:00.00 bitrate=31749258909.1kbits/s speed=5.27e-07x elapsed=0:00:20.87
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_06_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_06_300k.mp3
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x120606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_06_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     title           : Lecture 6: Recursion and Dictionaries
#     artist          : Prof. Eric Grimson
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-26T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, recursion, dictionary, divide-and-conquer, induction, factorial, tower of hanoi
#   Duration: 00:48:21.10, start: 0.000000, bitrate: 311 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 76 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:55.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_06_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     TIT2            : Lecture 6: Recursion and Dictionaries
#     TPE1            : Prof. Eric Grimson
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-26T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, recursion, dictionary, divide-and-conquer, induction, factorial, tower of hanoi
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x600003510480] video:2225KiB audio:45330KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.002830%
# frame=    1 fps=0.0 q=-0.0 Lsize=   47557KiB time=00:00:00.00 bitrate=35416816727.3kbits/s speed=4.7e-07x elapsed=0:00:23.40
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_07_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_07_300k.mp3
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x145606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_07_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Lecture 7: Testing, Debugging, Exceptions, and Assertions
#     episode_id      : 000
#     encoder         : Lavf55.18.100
#     rating          : 0
#     artist          : Dr. Ana Bell
#     date            : 2016-09-27T20:00:00Z
#     genre           : MIT Faculty Lectures
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     album_artist    : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     synopsis        : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     media_type      : 0
#     keywords        : Python, testing, debugging, exceptions, assertions, except, assert, black box, glass box
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#   Duration: 00:41:32.39, start: 0.000000, bitrate: 311 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 79 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x54, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-13T16:23:49.000000Z
#   Stream #0:3[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:3 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138628000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_07_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     TIT2            : Lecture 7: Testing, Debugging, Exceptions, and Assertions
#     episode_id      : 000
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     rating          : 0
#     TPE1            : Dr. Ana Bell
#     TDRC            : 2016-09-27T20:00:00Z
#     TCON            : MIT Faculty Lectures
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     TPE2            : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     synopsis        : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     media_type      : 0
#     keywords        : Python, testing, debugging, exceptions, assertions, except, assert, black box, glass box
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x600003850240] video:2275KiB audio:38944KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003317%
# frame=    1 fps=0.1 q=-0.0 Lsize=   41220KiB time=00:00:00.00 bitrate=30697909818.2kbits/s speed=5.62e-07x elapsed=0:00:19.58
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x11de06660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     title           : Lecture 10: Understanding Program Efficiency, Part 1
#     artist          : Prof. Eric Grimson
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : algorithmic complexity, big oh, runtime, complexity classes, efficiency, linear complexity, quadratic complexity
#   Duration: 00:51:25.72, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:18.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# File '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3' already exists. Overwrite? [y/N] Not overwriting - exiting
# Error opening output file /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3.
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x150606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_08_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     title           : Lecture 8: Object Oriented Programming
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-03T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, OOP, Object Oriented Programming, Class, Attribute
#   Duration: 00:41:43.64, start: 0.000000, bitrate: 314 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 78 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:04.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_10_300k.mp3
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_08_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_08_300k.mp3
# [swscaler @ 0x1483a8000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_08_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     TIT2            : Lecture 8: Object Oriented Programming
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-10-03T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, OOP, Object Oriented Programming, Class, Attribute
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x6000016d4240] video:2225KiB audio:39120KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003198%
# frame=    1 fps=0.1 q=-0.0 Lsize=   41346KiB time=00:00:00.00 bitrate=30791763636.4kbits/s speed=5.6e-07x elapsed=0:00:19.62
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x12b606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_09_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     title           : Lecture 9: Python Classes and Inheritance
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-05T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, Object Oriented Programming, OOP, attribute, getter, setter, instance, subclass, inheritance
#   Duration: 00:47:27.21, start: 0.000000, bitrate: 313 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 78 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:13.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1385d0000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_09_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     TIT2            : Lecture 9: Python Classes and Inheritance
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-10-05T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, Object Oriented Programming, OOP, attribute, getter, setter, instance, subclass, inheritance
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_09_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_09_300k.mp3
# [out#0/mp3 @ 0x600002738000] video:2225KiB audio:44488KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003121%
# frame=    1 fps=0.0 q=-0.0 Lsize=   46715KiB time=00:00:00.00 bitrate=34789653818.2kbits/s speed=4.97e-07x elapsed=0:00:22.14
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x132606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_02_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     title           : Lecture 2: Branching and Iteration
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, string, branching, conditionals, indentation, iteration, for loop, if loop
#   Duration: 00:43:30.13, start: 0.000000, bitrate: 316 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:28.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118128000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_02_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     TIT2            : Lecture 2: Branching and Iteration
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, string, branching, conditionals, indentation, iteration, for loop, if loop
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_02_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_02_300k.mp3
# [out#0/mp3 @ 0x600000f5c540] video:2225KiB audio:40784KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003442%
# frame=    1 fps=0.0 q=-0.0 Lsize=   43010KiB time=00:00:00.00 bitrate=32031014545.5kbits/s speed=5.09e-07x elapsed=0:00:21.62
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x127606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_03_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     title           : Lecture 3: String Manipulation, Guess and Check, Approximations, Bisection
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-14T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, strings, indexing, guess and check, approximation, bisection search
#   Duration: 00:45:01.03, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:36.000000Z
# ...
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x110628000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_03_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     TIT2            : Lecture 3: String Manipulation, Guess and Check, Approximations, Bisection
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-14T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, strings, indexing, guess and check, approximation, bisection search
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_03_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_03_300k.mp3
# [out#0/mp3 @ 0x60000285c240] video:2225KiB audio:42204KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003216%
# frame=    1 fps=0.0 q=-0.0 Lsize=   44431KiB time=00:00:00.00 bitrate=33088861090.9kbits/s speed=4.95e-07x elapsed=0:00:22.21
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x124f04310] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_05_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     title           : Lecture 5: Tuples, Lists, Aliasing, Mutability, and Cloning
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-21T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, lists, tuples, aliasing, mutability, cloning, compound data types
#   Duration: 00:41:27.15, start: 0.000000, bitrate: 316 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:47.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128768000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_05_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     TIT2            : Lecture 5: Tuples, Lists, Aliasing, Mutability, and Cloning
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-21T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, lists, tuples, aliasing, mutability, cloning, compound data types
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_05_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_05_300k.mp3
# [out#0/mp3 @ 0x600003268240] video:2225KiB audio:38862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003489%
# frame=    1 fps=0.0 q=-0.0 Lsize=   41089KiB time=00:00:00.00 bitrate=30599986181.8kbits/s speed=5.37e-07x elapsed=0:00:20.50
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x149e06660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_04_300k.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     title           : Lecture 4: Decomposition, Abstraction, and Functions
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-19T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, program structure, functions, specifications, scope, return, print
#   Duration: 00:41:08.39, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 79 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:42.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1406c0000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to '/Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_04_300k.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     TIT2            : Lecture 4: Decomposition, Abstraction, and Functions
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-19T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, program structure, functions, specifications, scope, return, print
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converting: /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_04_300k.mp4 → /Users/frolt/Git Projects/Data_Science/DS_ML_Projects/RAGbasedAI_assistant/videos/MIT6_0001F16_Lecture_04_300k.mp3
# [out#0/mp3 @ 0x600001bb8300] video:2225KiB audio:38569KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003581%
# frame=    1 fps=0.0 q=-0.0 Lsize=   40796KiB time=00:00:00.00 bitrate=30381615272.7kbits/s speed=5.46e-07x elapsed=0:00:20.14

# %%
import os 
import subprocess                     # Subprocess is a built-in Python module that lets Python run external programs.

folder = "videos"
files = os.listdir(folder)

os.makedirs("audios", exist_ok=True)   # ensures "audios" folder exists so ffmpeg can save output

for file in files:
    print(file)

    if not file.endswith((".mp3", ".mp4")):     # only process mp3/mp4 files
        continue


    # PART 1: Extract lecture number


    if file.startswith("Lecture_"):  

        name_without_ext = file.rsplit(".", 1)[0]      # Lecture_8
        parts_simple = name_without_ext.split("_")     # ["Lecture", "8"]

        if len(parts_simple) < 2:
            print("Skipping (unexpected filename):", file)
            continue

        try:
            lec_num = int(parts_simple[1])     # converts "8" into int 8
        except ValueError:
            print("Skipping (lecture number not numeric):", file)
            continue

    else:
        # original MIT6 filename format: MIT6_0001F16_Lecture_01_300k.mp4
        parts = file.split("_")

        if len(parts) < 4:                     # prevents IndexError when parts[3] doesn't exist
            print("Skipping (unexpected filename):", file)
            continue

        try:
            lec_num = int(parts[3])           # converts "01" → 1 into int
        except ValueError:
            print("Skipping (lecture number not numeric):", file)
            continue


    # PART 2: Rename the file
    

    ext = file.split(".")[-1]                 # extract extension (mp4/mp3)
    new_name = f"Lecture_{lec_num}.{ext}"     # new format filename: Lecture_8.mp4

    old = os.path.join(folder, file)          # full path to old file
    new = os.path.join(folder, new_name)      # full path to new file

    # rename only if the name is not already correct
    if old != new:
        os.rename(old, new)
        print(f"Renamed to → {new_name}")
    else:
        print(f"Already correct name → {new_name}")


    # PART 3: Convert MP4 to MP3 using ffmpeg


    if ext.lower() == "mp4":            # ONLY convert videos (.mp4), not audio (.mp3)
        output_name = f"Lecture_{lec_num}.mp3"                 # make clean mp3 name
        output_path = os.path.join("audios", output_name)      # path: audios/Lecture_8.mp3

        subprocess.run([
            "ffmpeg",
            "-i", new,            # input: the renamed mp4 file
            output_path           # output: mp3 inside audios folder
        ])

        print(f"Converted → {output_name}")
    else:
        print("No conversion needed (already mp3):", new_name)
# Out:
# Lecture_8.mp3
# Already correct name → Lecture_8.mp3
# No conversion needed (already mp3): Lecture_8.mp3
# .DS_Store
# Lecture_8.mp4
# Already correct name → Lecture_8.mp4
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x143606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     title           : Lecture 8: Object Oriented Programming
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-03T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, OOP, Object Oriented Programming, Class, Attribute
#   Duration: 00:41:43.64, start: 0.000000, bitrate: 314 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 78 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:04.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148080000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_8.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     TIT2            : Lecture 8: Object Oriented Programming
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-10-03T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces Object Oriented Programming and discusses its representation in Python.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, OOP, Object Oriented Programming, Class, Attribute
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x600002d08240] video:2225KiB audio:39120KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003198%
# frame=    1 fps=0.1 q=-0.0 Lsize=   41346KiB time=00:00:00.00 bitrate=30791763636.4kbits/s speed=5.66e-07x elapsed=0:00:19.43
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x126606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     title           : Lecture 9: Python Classes and Inheritance
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-05T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, Object Oriented Programming, OOP, attribute, getter, setter, instance, subclass, inheritance
#   Duration: 00:47:27.21, start: 0.000000, bitrate: 313 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 78 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:13.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x130008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_9.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     TIT2            : Lecture 9: Python Classes and Inheritance
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-10-05T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell continues the discussion of Object Oriented Programming in Python, with an emphasis on data control, inheritance, and subclasses.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, Object Oriented Programming, OOP, attribute, getter, setter, instance, subclass, inheritance
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_8.mp3
# Lecture_9.mp4
# Already correct name → Lecture_9.mp4
# [out#0/mp3 @ 0x600001410240] video:2225KiB audio:44488KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003121%
# frame=    1 fps=0.0 q=-0.0 Lsize=   46715KiB time=00:00:00.00 bitrate=34789653818.2kbits/s speed=5e-07x elapsed=0:00:22.00
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x158e06660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_10.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     title           : Lecture 10: Understanding Program Efficiency, Part 1
#     artist          : Prof. Eric Grimson
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-10-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : algorithmic complexity, big oh, runtime, complexity classes, efficiency, linear complexity, quadratic complexity
#   Duration: 00:51:25.72, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:54:18.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1504f0000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_10.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     TIT2            : Lecture 10: Understanding Program Efficiency, Part 1
#     TPE1            : Prof. Eric Grimson
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-10-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces algorithmic complexity, a rough measure of the efficiency of a program. He then discusses Big "Oh" notation and different complexity classes.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : algorithmic complexity, big oh, runtime, complexity classes, efficiency, linear complexity, quadratic complexity
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_9.mp3
# Lecture_9.mp3
# Already correct name → Lecture_9.mp3
# No conversion needed (already mp3): Lecture_9.mp3
# Lecture_10.mp4
# Already correct name → Lecture_10.mp4
# [out#0/mp3 @ 0x60000270c540] video:2225KiB audio:48215KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003055%
# frame=    1 fps=0.0 q=-0.0 Lsize=   50441KiB time=00:00:00.00 bitrate=37565128000.0kbits/s speed=4.36e-07x elapsed=0:00:25.23
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x125606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Lecture 7: Testing, Debugging, Exceptions, and Assertions
#     episode_id      : 000
#     encoder         : Lavf55.18.100
#     rating          : 0
#     artist          : Dr. Ana Bell
#     date            : 2016-09-27T20:00:00Z
#     genre           : MIT Faculty Lectures
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     album_artist    : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     synopsis        : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     media_type      : 0
#     keywords        : Python, testing, debugging, exceptions, assertions, except, assert, black box, glass box
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#   Duration: 00:41:32.39, start: 0.000000, bitrate: 311 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 79 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x54, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-13T16:23:49.000000Z
#   Stream #0:3[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:3 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x108008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_7.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     TIT2            : Lecture 7: Testing, Debugging, Exceptions, and Assertions
#     episode_id      : 000
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     rating          : 0
#     TPE1            : Dr. Ana Bell
#     TDRC            : 2016-09-27T20:00:00Z
#     TCON            : MIT Faculty Lectures
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     TPE2            : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     synopsis        : In this lecture, Dr. Bell discusses testing, debugging, and exceptions and assertion statements in Python.
#     media_type      : 0
#     keywords        : Python, testing, debugging, exceptions, assertions, except, assert, black box, glass box
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_10.mp3
# Lecture_10.mp3
# Already correct name → Lecture_10.mp3
# No conversion needed (already mp3): Lecture_10.mp3
# Lecture_7.mp3
# Already correct name → Lecture_7.mp3
# No conversion needed (already mp3): Lecture_7.mp3
# Lecture_7.mp4
# Already correct name → Lecture_7.mp4
# [out#0/mp3 @ 0x6000013c8240] video:2275KiB audio:38944KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003317%
# frame=    1 fps=0.0 q=-0.0 Lsize=   41220KiB time=00:00:00.00 bitrate=30697909818.2kbits/s speed=5.49e-07x elapsed=0:00:20.02
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x11fe06660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     title           : Lecture 6: Recursion and Dictionaries
#     artist          : Prof. Eric Grimson
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-26T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, recursion, dictionary, divide-and-conquer, induction, factorial, tower of hanoi
#   Duration: 00:48:21.10, start: 0.000000, bitrate: 311 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 76 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:55.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1284a8000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_6.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     TIT2            : Lecture 6: Recursion and Dictionaries
#     TPE1            : Prof. Eric Grimson
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-26T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Prof. Grimson introduces the concept of recursion and the Python dictionary data type.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, recursion, dictionary, divide-and-conquer, induction, factorial, tower of hanoi
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_7.mp3
# Lecture_6.mp4
# Already correct name → Lecture_6.mp4
# [out#0/mp3 @ 0x600000f54480] video:2225KiB audio:45330KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.002830%
# frame=    1 fps=0.0 q=-0.0 Lsize=   47557KiB time=00:00:00.00 bitrate=35416816727.3kbits/s speed=4.71e-07x elapsed=0:00:23.34
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x144e06660] stream 0, timescale not set
# Converted → Lecture_6.mp3
# Lecture_6.mp3
# Already correct name → Lecture_6.mp3
# No conversion needed (already mp3): Lecture_6.mp3
# Lecture_4.mp3
# Already correct name → Lecture_4.mp3
# No conversion needed (already mp3): Lecture_4.mp3
# Lecture_4.mp4
# Already correct name → Lecture_4.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     title           : Lecture 4: Decomposition, Abstraction, and Functions
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-19T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, program structure, functions, specifications, scope, return, print
#   Duration: 00:41:08.39, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 79 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:42.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_4.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     TIT2            : Lecture 4: Decomposition, Abstraction, and Functions
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-19T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses program structuring, functions, specifications, scoping, and the difference between the "return" and "print" keywords in Python.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, program structure, functions, specifications, scope, return, print
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x6000006f4300] video:2225KiB audio:38569KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003581%
# frame=    1 fps=0.0 q=-0.0 Lsize=   40796KiB time=00:00:00.00 bitrate=30381615272.7kbits/s speed=5.48e-07x elapsed=0:00:20.07
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x11ce06660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     title           : Lecture 5: Tuples, Lists, Aliasing, Mutability, and Cloning
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-21T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, lists, tuples, aliasing, mutability, cloning, compound data types
#   Duration: 00:41:27.15, start: 0.000000, bitrate: 316 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:47.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120078000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_5.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     TIT2            : Lecture 5: Tuples, Lists, Aliasing, Mutability, and Cloning
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-21T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces compound data types, such as lists and tuples, and explains the concepts of aliasing, mutability, and cloning.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, lists, tuples, aliasing, mutability, cloning, compound data types
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_4.mp3
# Lecture_5.mp4
# Already correct name → Lecture_5.mp4
# [out#0/mp3 @ 0x600001884480] video:2225KiB audio:38862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003489%
# frame=    1 fps=0.0 q=-0.0 Lsize=   41089KiB time=00:00:00.00 bitrate=30599986181.8kbits/s speed=5.37e-07x elapsed=0:00:20.47
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x150e06660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : Lecture 1: What is Computation?
#     episode_id      : 000
#     encoder         : Lavf55.18.100
#     rating          : 0
#     artist          : Dr. Ana Bell
#     date            : 2016-09-06T20:00:00Z
#     genre           : MIT Faculty Lecture
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     album_artist    : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     synopsis        : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     media_type      : 0
#     keywords        : Python, theory of computation, syntax, programming language
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#   Duration: 00:43:05.96, start: 0.000000, bitrate: 312 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, start 0.044000 (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x54, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2019-07-30T18:45:22.000000Z
#   Stream #0:3[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:3 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x158080000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_1.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     TIT2            : Lecture 1: What is Computation?
#     episode_id      : 000
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     rating          : 0
#     TPE1            : Dr. Ana Bell
#     TDRC            : 2016-09-06T20:00:00Z
#     TCON            : MIT Faculty Lecture
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     TPE2            : MIT OpenCourseWare
#     description     : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     synopsis        : In this lecture, Dr. Bell introduces the theory of computation and explains some aspects of computational thinking. Programming languages are discussed, with an emphasis on basic Python syntax and data structures.
#     media_type      : 0
#     keywords        : Python, theory of computation, syntax, programming language
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_5.mp3
# Lecture_5.mp3
# Already correct name → Lecture_5.mp3
# No conversion needed (already mp3): Lecture_5.mp3
# Lecture_1.mp3
# Already correct name → Lecture_1.mp3
# No conversion needed (already mp3): Lecture_1.mp3
# Lecture_1.mp4
# Already correct name → Lecture_1.mp4
# [out#0/mp3 @ 0x600002de4000] video:2225KiB audio:40406KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003569%
# frame=    1 fps=0.0 q=-0.0 Lsize=   42632KiB time=00:00:00.00 bitrate=31749258909.1kbits/s speed=5.28e-07x elapsed=0:00:20.82
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Converted → Lecture_1.mp3
# Lecture_2.mp3
# Already correct name → Lecture_2.mp3
# No conversion needed (already mp3): Lecture_2.mp3
# Lecture_2.mp4
# Already correct name → Lecture_2.mp4
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x133606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     title           : Lecture 2: Branching and Iteration
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, string, branching, conditionals, indentation, iteration, for loop, if loop
#   Duration: 00:43:30.13, start: 0.000000, bitrate: 316 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:28.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128628000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_2.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     TIT2            : Lecture 2: Branching and Iteration
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-12T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell introduces strings and indentation in Python, then discusses basic features of programmatic logic, such as branching, conditionals, iteration, and loops.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, string, branching, conditionals, indentation, iteration, for loop, if loop
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [out#0/mp3 @ 0x600002fd06c0] video:2225KiB audio:40784KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003442%
# frame=    1 fps=0.0 q=-0.0 Lsize=   43010KiB time=00:00:00.00 bitrate=32031014545.5kbits/s speed=5.1e-07x elapsed=0:00:21.55
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/8.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b606660] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/Lecture_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     title           : Lecture 3: String Manipulation, Guess and Check, Approximations, Bisection
#     artist          : Dr. Ana Bell
#     album_artist    : MIT OpenCourseWare
#     album           : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     genre           : MIT Faculty Lecture
#     date            : 2016-09-14T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     copyright       : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     encoder         : Lavf55.18.100
#     media_type      : 9
#     rating          : 0
#     keywords        : Python, strings, indexing, guess and check, approximation, bisection search
#   Duration: 00:45:01.03, start: 0.000000, bitrate: 315 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 4:3 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 90k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbn
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 80 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:3[0x4](eng): Subtitle: mov_text (tx3g / 0x67337874), 640x210, 0 kb/s (default)
#     Metadata:
#       creation_time   : 2017-01-06T18:53:36.000000Z
#   Stream #0:4[0x0]: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 1400x1400 [SAR 72:72 DAR 1:1], 90k tbr, 90k tbn (attached pic)
# Stream mapping:
#   Stream #0:4 -> #0:0 (mjpeg (native) -> png (native))
#   Stream #0:2 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140088000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mp3, to 'audios/Lecture_3.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     synopsis        : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     TIT2            : Lecture 3: String Manipulation, Guess and Check, Approximations, Bisection
#     TPE1            : Dr. Ana Bell
#     TPE2            : MIT OpenCourseWare
#     TALB            : MIT OCW: 6.0001 Introduction to Computer Science and Programming in Python, Fall 2016
#     comment         : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     TCON            : MIT Faculty Lecture
#     TDRC            : 2016-09-14T04:00:00Z
#     episode_id      : 000
#     description     : In this lecture, Dr. Bell discusses string manipulation, guess-and-check algorithms, approximate solution methods, and bisection search.
#     TCOP            : http://ocw.mit.edu; Creative Commons Attribution-NonCommercial-ShareAlike 4.0; http://ocw.mit.edu/terms; Album art image byDboybaker on Flickr.
#     keywords        : Python, strings, indexing, guess and check, approximation, bisection search
#     media_type      : 9
#     rating          : 0
#     TSSE            : Lavf62.3.100
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 1400x1400 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 90k fps, 90k tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.11.100 png
#   Stream #0:1(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libmp3lame
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Converted → Lecture_2.mp3
# Lecture_3.mp4
# Already correct name → Lecture_3.mp4
# frame=    0 fps=0.0 q=0.0 size=       1KiB time=N/A bitrate=N/A speed=N/A elapsed=0:00:21.71
# Converted → Lecture_3.mp3
# Lecture_3.mp3
# Already correct name → Lecture_3.mp3
# No conversion needed (already mp3): Lecture_3.mp3
# [out#0/mp3 @ 0x600002358240] video:2225KiB audio:42204KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003216%
# frame=    1 fps=0.0 q=-0.0 Lsize=   44431KiB time=00:00:00.00 bitrate=33088861090.9kbits/s speed=4.97e-07x elapsed=0:00:22.15
